# %%
# Scrape the data
# %run scraping.py

# %%
# Clean the data
# %run cleaning.py

# %%
df
# Out:
#                             _id  Unnamed: 0      ID                    Name  \
# 0      60803e1def3b459970223144           0  188289        Emmanuel Rivière
# 1      60803e1def3b459970223145           1  245371           Thiago Almada
# 2      60803e1def3b459970223146           2  190683              Ryan Mason
# 3      60803e1def3b459970223147           3    8517            Scott Parker
# 4      60803e1def3b459970223148           4  176048              Kei Kamara
# ...                         ...         ...     ...                     ...
# 18074  60803e1eef3b4599702277de       18074  228464            Jin Hyuk Kim
# 18075  60803e1eef3b4599702277df       18075  228503       Yeong Chong Jeong
# 18076  60803e1eef3b4599702277e0       18076  228508            Fabian Kalig
# 18077  60803e1eef3b4599702277e1       18077  228544           Sofiane Daham
# 18078  60803e1eef3b4599702277e2       18078  228552  Edison Luiz dos Santos
#
# ...
