# %%
#scraping WordMeter Website for Countries Population Data 
#based on https://towardsdatascience.com/how-to-web-scrape-in-8-minutes-4a100a672397
#pip install beautifulsoup4 
#pip install lxml
import pymongo
import requests

import pandas as pd

print("Reading data From DB")
client = pymongo.MongoClient("mongodb+srv://m001-student:m001-mongodb-basics@cluster0.laxah.mongodb.net/myFirstDatabase?retryWrites=true&w=majority", serverSelectionTimeoutMS = 5000)
db=client.marcin

#coll=db.covid_data #dropping teh data before inserting.
countries=['Austria','Poland', 'Germany', 'Ireland', 'Italy', 'France', 'Spain', 'Portugal', 'Norway', 'Sweden']
obesity_list=[]
country_list=[]
population_list=[]
covid_deaths_list=[]
for country in countries:
    #population
    coll=db.population_data 
    x=coll.find({'Country':country}, {'_id':0, 'Country':1, 'Population':1})
    for data in x:
        population_list.append(data['Population'])
        country_list.append(data['Country'])
    
    #obesity data
    coll=db.obesity_data 
    x=coll.find({'Country':country}, {'_id':0, 'Obesity_percentage':1})
    for data in x:
        obesity_list.append(data['Obesity_percentage'])
    
    #covid data
    coll=db.covid_data 
    x=coll.find({'location':country}, {'_id':0, 'deaths':1})
    for data in x:
        covid_deaths_list.append(data['deaths'])
        
    #drukuj listy  
print(f"list countries {country_list}")
print(f"list population {population_list}")
print(f"list obesity {obesity_list}")
print(f"list covid {covid_deaths_list}")

data= { 'Country':country_list, 
       'Population':population_list, 
       'Obesity_percentage':obesity_list, 
        'covid_deaths':covid_deaths_list}

df=pd.DataFrame(data)
df
# Out:
# Reading data From DB
# list countries ['Austria', 'Poland', 'Germany', 'Ireland', 'Italy', 'France', 'Spain', 'Portugal', 'Norway', 'Sweden']
# list population [9006398, 37846611, 83783942, 4937786, 60461826, 65273511, 46754778, 10196709, 5421241, 10099265]
# list obesity ['21.90000', '25.60000', '25.70000', '26.90000', '22.90000', '23.20000', '27.10000', '23.20000', '25.00000', '22.10000']
# list covid [9687, 58421, 78500, 4785, 114254, 98909, 76328, 16916, 684, 13621]
#     Country  Population Obesity_percentage  covid_deaths
# 0   Austria     9006398           21.90000          9687
# 1    Poland    37846611           25.60000         58421
# 2   Germany    83783942           25.70000         78500
# 3   Ireland     4937786           26.90000          4785
# 4     Italy    60461826           22.90000        114254
# 5    France    65273511           23.20000         98909
# 6     Spain    46754778           27.10000         76328
# 7  Portugal    10196709           23.20000         16916
# 8    Norway     5421241           25.00000           684
# 9    Sweden    10099265           22.10000         13621

# %%
df['covid_death_percentage']=df['covid_deaths']/df['Population']

# %%
df
# Out:
#     Country  Population Obesity_percentage  covid_deaths  \
# 0   Austria     9006398           21.90000          9687
# 1    Poland    37846611           25.60000         58421
# 2   Germany    83783942           25.70000         78500
# 3   Ireland     4937786           26.90000          4785
# 4     Italy    60461826           22.90000        114254
# 5    France    65273511           23.20000         98909
# 6     Spain    46754778           27.10000         76328
# 7  Portugal    10196709           23.20000         16916
# 8    Norway     5421241           25.00000           684
# 9    Sweden    10099265           22.10000         13621
#
#    covid_death_percentage
# 0                0.001076
# 1                0.001544
# 2                0.000937
# 3                0.000969
# 4                0.001890
# 5                0.001515
# 6                0.001633
# 7                0.001659
# 8                0.000126
# 9                0.001349

# %%
import matplotlib.pyplot as plt
df.plot(x ='Obesity_percentage', y='covid_death_percentage', kind = 'scatter')
plt.show()
