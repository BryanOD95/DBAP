# %%
# Json API (found here: https://www.programmableweb.com/api/covid2019-rest-api-v10)
import pymongo
import requests
#Getting the Full  https://covid2019-api.herokuapp.com/v2/current

#average temperature 

def get_current_covid_info_for_all_countries():
    res=requests.get('https://covid2019-api.herokuapp.com/v2/current');
    #print(res.json())
    return res.json();

def print_country_covid_info(result):
    
    list_of_entries=result['data']
    print("inserting to MongoDB")
    print(list_of_entries)
    client = pymongo.MongoClient("mongodb+srv://m001-student:m001-mongodb-basics@cluster0.laxah.mongodb.net/myFirstDatabase?retryWrites=true&w=majority", serverSelectionTimeoutMS = 5000)
    db=client.marcin
    coll=db.covid_data #dropping teh data before inserting.
    coll.drop()
    coll.insert_many(list_of_entries)

def get(result):
    list_of_entries=result['data']
    print("inserting to MongoDB")
    client = pymongo.MongoClient("mongodb+srv://m001-student:m001-mongodb-basics@cluster0.laxah.mongodb.net/myFirstDatabase?retryWrites=true&w=majority", serverSelectionTimeoutMS = 5000)
    db=client.marcin
    coll=db.covid_data #dropping teh data before inserting.
    coll.drop()
    coll.insert_many(list_of_entries)

    
    
def main():
    try:
      w_data=get_current_covid_info_for_all_countries();
    except:
      print('API call failed...')
    print_country_covid_info(w_data)
if __name__=='__main__':
    main()
# Out:
# inserting to MongoDB
# [{'location': 'US', 'confirmed': 31151495, 'deaths': 561783, 'recovered': 0, 'active': 0}, {'location': 'Brazil', 'confirmed': 13445006, 'deaths': 351334, 'recovered': 11739649, 'active': 1354023}, {'location': 'India', 'confirmed': 13358805, 'deaths': 169275, 'recovered': 12081443, 'active': 1108087}, {'location': 'France', 'confirmed': 5001685, 'deaths': 98213, 'recovered': 312540, 'active': 4589427}, {'location': 'Russia', 'confirmed': 4580633, 'deaths': 100949, 'recovered': 4209754, 'active': 269930}, {'location': 'United Kingdom', 'confirmed': 4382880, 'deaths': 127324, 'recovered': 13494, 'active': 4242062}, {'location': 'Turkey', 'confirmed': 3798333, 'deaths': 33702, 'recovered': 3301217, 'active': 463414}, {'location': 'Italy', 'confirmed': 3754077, 'deaths': 113923, 'recovered': 3107069, 'active': 533085}, {'location': 'Spain', 'confirmed': 3347512, 'deaths': 76328, 'recovered': 150376, 'active': 3120808}, {'location': 'Germany', 'confirmed': 3009452, 'deaths': 78402, 'recovered': 2668910, 'active': 262140}, {'location': 'Poland', 'confirmed': 2552898, 'deaths': 58176, 'recovered': 2143065, 'active': 351657}, {'location': 'Colombia', 'confirmed': 2518715, 'deaths': 65608, 'recovered': 2375176, 'active': 77931}, {'location': 'Argentina', 'confirmed': 2517300, 'deaths': 57647, 'recovered': 2217783, 'active': 241870}, {'location': 'Mexico', 'confirmed': 2278420, 'deaths': 209212, 'recovered': 1765244, 'active': 303964}, {'location': 'Iran', 'confirmed': 2049078, 'deaths': 64232, 'recovered': 1702062, 'active': 282784}, {'location': 'Ukraine', 'confirmed': 1893192, 'deaths': 38479, 'recovered': 1454351, 'active': 400362}, {'location': 'Peru', 'confirmed': 1639767, 'deaths': 54669, 'recovered': 1557779, 'active': 27319}, {'location': 'Czechia', 'confirmed': 1577972, 'deaths': 27734, 'recovered': 1448843, 'active': 101395}, {'location': 'Indonesia', 'confirmed': 1562868, 'deaths': 42443, 'recovered': 1409288, 'active': 111137}, {'location': 'South Africa', 'confirmed': 1557527, 'deaths': 53256, 'recovered': 1482682, 'active': 21589}, {'location': 'Netherlands', 'confirmed': 1366024, 'deaths': 16939, 'recovered': 18054, 'active': 1331031}, {'location': 'Chile', 'confirmed': 1068522, 'deaths': 24213, 'recovered': 998400, 'active': 45910}, {'location': 'Canada', 'confirmed': 1060052, 'deaths': 23270, 'recovered': 967364, 'active': 69419}, {'location': 'Romania', 'confirmed': 1002865, 'deaths': 25006, 'recovered': 902239, 'active': 75620}, {'location': 'Belgium', 'confirmed': 922487, 'deaths': 23428, 'recovered': 0, 'active': 899059}, {'location': 'Iraq', 'confirmed': 918155, 'deaths': 14678, 'recovered': 809663, 'active': 93814}, {'location': 'Sweden', 'confirmed': 857401, 'deaths': 13621, 'recovered': 0, 'active': 843780}, {'location': 'Philippines', 'confirmed': 853209, 'deaths': 14744, 'recovered': 648220, 'active': 190245}, {'location': 'Israel', 'confirmed': 835813, 'deaths': 6292, 'recovered': 825519, 'active': 4002}, {'location': 'Portugal', 'confirmed': 826928, 'deaths': 16910, 'recovered': 784208, 'active': 25810}, {'location': 'Pakistan', 'confirmed': 721018, 'deaths': 15443, 'recovered': 631700, 'active': 73875}, {'location': 'Hungary', 'confirmed': 713868, 'deaths': 23211, 'recovered': 423366, 'active': 267291}, {'location': 'Bangladesh', 'confirmed': 678937, 'deaths': 9661, 'recovered': 572378, 'active': 96898}, {'location': 'Jordan', 'confirmed': 662395, 'deaths': 7708, 'recovered': 588353, 'active': 66334}, {'location': 'Serbia', 'confirmed': 639476, 'deaths': 5700, 'recovered': 0, 'active': 633776}, {'location': 'Switzerland', 'confirmed': 617543, 'deaths': 10452, 'recovered': 317600, 'active': 289491}, {'location': 'Austria', 'confirmed': 574755, 'deaths': 9662, 'recovered': 532539, 'active': 32554}, {'location': 'Japan', 'confirmed': 503537, 'deaths': 9352, 'recovered': 458684, 'active': 35501}, {'location': 'Morocco', 'confirmed': 501688, 'deaths': 8891, 'recovered': 488015, 'active': 4782}, {'location': 'L ...

# %%
# Test of Json API (found here: https://www.programmableweb.com/api/covid2019-rest-api-v10)
import requests

def get_country_covid_info(query):
    res=requests.get('https://covid2019-api.herokuapp.com/v2/country/'+query);
    print(res.json())
    return res.json();

def print_country_covid_info(result,country):
    print('----'*20)
    print(f" Confirmed cases in {country}: {result['data']['confirmed']}")
    print(f" Deaths in {country}:  {result['data']['deaths']}")
#    print("Wind speed: {} m/s".format(result['wind']['speed']))
#    print("Description: {}".format(result['weather'][0]['description']))
#    print("Weather: {}".format(result['weather'][0]['main']))

def main():
    country=input('Enter country: ')
    print()
    try:
      query=country;
      w_data=get_country_covid_info(query);
      print_country_covid_info(w_data, country)
    except:
      print('API call failed...')
if __name__=='__main__':
    main()
# Out:
# Enter country: Poland
#
# {'data': {'location': 'Poland', 'confirmed': 2528006, 'deaths': 57427, 'recovered': 2107776, 'active': 362803}, 'dt': '04-10-2021', 'ts': 1618012800}
# --------------------------------------------------------------------------------
#  Confirmed cases in Poland: 2528006
#  Deaths in Poland:  57427

# %%
# Question 4
import xml.etree.ElementTree as ET
import csv

xmlFile = "people.xml"
tree = ET.parse(xmlFile)
root = tree.getroot()

# open a file for writing

csvFile = "residentData.csv"

Resident_data = open(csvFile, 'w')

# create the csv writer object

csvwriter = csv.writer(Resident_data)
resident_head = []

count = 0
for member in root.findall('Resident'):
    resident = []
    address_list = []
    if count == 0:
        name = member.find('Name').tag
        resident_head.append(name)
        PhoneNumber = member.find('PhoneNumber').tag
        resident_head.append(PhoneNumber)
        EmailAddress = member.find('EmailAddress').tag
        resident_head.append(EmailAddress)
        Address = member[3].tag
        resident_head.append(Address)
        csvwriter.writerow(resident_head)
        count = count + 1

    name = member.find('Name').text
    resident.append(name)
    PhoneNumber = member.find('PhoneNumber').text
    resident.append(PhoneNumber)
    EmailAddress = member.find('EmailAddress').text
    resident.append(EmailAddress)
    Address = member[3][0].text
    address_list.append(Address)
    City = member[3][1].text
    address_list.append(City)
    StateCode = member[3][2].text
    address_list.append(StateCode)
    PostalCode = member[3][3].text
    address_list.append(PostalCode)
    resident.append(address_list)
    csvwriter.writerow(resident)

Resident_data.close()

# %%
#scraping WordMeter Website
#based on https://towardsdatascience.com/how-to-web-scrape-in-8-minutes-4a100a672397

# %%
#pip install beautifulsoup4 
#pip install lxml
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
url = 'https://www.worldometers.info/world-population/population-by-country/'
requests.get(url)
page = requests.get(url)
#page
soup = BeautifulSoup(page.text, 'lxml')
#print(soup)
table_data = soup.find('table', class_ = 'table table-striped table-bordered')
#print(table_data)
headers = []
for i in table_data.find_all('th'):
    title = i.text
    headers.append(title)
df = pd.DataFrame(columns = headers)    
#df
for j in table_data.find_all('tr')[1:]:
        row_data = j.find_all('td')
        row = [tr.text for tr in row_data]
        length = len(df)
        df.loc[length] = row
#df

# %%
df
# Out:
#        # Country (or dependency) Population (2020) Yearly Change  Net Change  \
# 0      1                   China     1,439,323,776        0.39 %   5,540,090
# 1      2                   India     1,380,004,385        0.99 %  13,586,631
# 2      3           United States       331,002,651        0.59 %   1,937,734
# 3      4               Indonesia       273,523,615        1.07 %   2,898,047
# 4      5                Pakistan       220,892,340        2.00 %   4,327,022
# ..   ...                     ...               ...           ...         ...
# 230  231              Montserrat             4,992        0.06 %           3
# 231  232        Falkland Islands             3,480        3.05 %         103
# 232  233                    Niue             1,626        0.68 %          11
# 233  234                 Tokelau             1,357        1.27 %          17
# 234  235                Holy See               801        0.25 %           2
#
#     Density (P/Km²) Land Area (Km²) Migrants (net) Fert. Rate Med. Age  \
# 0               153       9,388,211       -348,399        1.7       38
# 1               464       2,973,190       -532,687        2.2       28
# 2                36       9,147,420        954,806        1.8       38
# 3               151       1,811,570        -98,955        2.3       30
# 4               287         770,880       -233,379        3.6       23
# ..              ...             ...            ...        ...      ...
# 230              50             100                      N.A.     N.A.
# 231               0          12,170                      N.A.     N.A.
# 232               6             260                      N.A.     N.A.
# 233             136              10                      N.A.     N.A.
# 234           2,003               0                      N.A.     N.A.
#
#     Urban Pop % World Share
# 0          61 %     18.47 %
# 1          35 %     17.70 %
# 2          83 %      4.25 %
# 3          56 %      3.51 %
# 4          35 %      2.83 %
# ..          ...         ...
# 230        10 %      0.00 %
# 231        66 %      0.00 %
# 232        46 %      0.00 %
# 233         0 %      0.00 %
# 234        N.A.      0.00 %
#
# [235 rows x 12 columns]

# %%
#{'location': 'US', 'confirmed': 31151495, 'deaths': 561783, 'recovered': 0, 'active': 0}

for index, row in df.iterrows():
    print (row["Country (or dependency)"], int(row["Population (2020)"].replace(',','')))
    d={}
    d['Country']=row["Country (or dependency)"]
    d['Population']=int(row["Population (2020)"].replace(',',''))    
    print(d)
# Out:
# China 1439323776
# {'Country': 'China', 'Population': 1439323776}
# India 1380004385
# {'Country': 'India', 'Population': 1380004385}
# United States 331002651
# {'Country': 'United States', 'Population': 331002651}
# Indonesia 273523615
# {'Country': 'Indonesia', 'Population': 273523615}
# Pakistan 220892340
# {'Country': 'Pakistan', 'Population': 220892340}
# Brazil 212559417
# {'Country': 'Brazil', 'Population': 212559417}
# Nigeria 206139589
# {'Country': 'Nigeria', 'Population': 206139589}
# Bangladesh 164689383
# {'Country': 'Bangladesh', 'Population': 164689383}
# Russia 145934462
# {'Country': 'Russia', 'Population': 145934462}
# Mexico 128932753
# {'Country': 'Mexico', 'Population': 128932753}
# Japan 126476461
# {'Country': 'Japan', 'Population': 126476461}
# Ethiopia 114963588
# {'Country': 'Ethiopia', 'Population': 114963588}
# Philippines 109581078
# {'Country': 'Philippines', 'Population': 109581078}
# Egypt 102334404
# {'Country': 'Egypt', 'Population': 102334404}
# Vietnam 97338579
# {'Country': 'Vietnam', 'Population': 97338579}
# DR Congo 89561403
# {'Country': 'DR Congo', 'Population': 89561403}
# Turkey 84339067
# {'Country': 'Turkey', 'Population': 84339067}
# Iran 83992949
# {'Country': 'Iran', 'Population': 83992949}
# Germany 83783942
# {'Country': 'Germany', 'Population': 83783942}
# Thailand 69799978
# {'Country': 'Thailand', 'Population': 69799978}
# United Kingdom 67886011
# {'Country': 'United Kingdom', 'Population': 67886011}
# France 65273511
# {'Country': 'France', 'Population': 65273511}
# Italy 60461826
# {'Country': 'Italy', 'Population': 60461826}
# Tanzania 59734218
# {'Country': 'Tanzania', 'Population': 59734218}
# South Africa 59308690
# {'Country': 'South Africa', 'Population': 59308690}
# Myanmar 54409800
# {'Country': 'Myanmar', 'Population': 54409800}
# Kenya 53771296
# {'Country': 'Kenya', 'Population': 53771296}
# South Korea 51269185
# {'Country': 'South Korea', 'Population': 51269185}
# Colombia 50882891
# {'Country': 'Colombia', 'Population': 50882891}
# Spain 46754778
# {'Country': 'Spain', 'Population': 46754778}
# Uganda 45741007
# {'Country': 'Uganda', 'Population': 45741007}
# Argentina 45195774
# {'Country': 'Argentina', 'Population': 45195774}
# Algeria 43851044
# {'Country': 'Algeria', 'Population': 43851044}
# Sudan 43849260
# {'Country': 'Sudan', 'Population': 43849260}
# Ukraine 43733762
# {'Country': 'Ukraine', 'Population': 43733762}
# Iraq 40222493
# {'Country': 'Iraq', 'Population': 40222493}
# Afghanistan 38928346
# {'Country': 'Afghanistan', 'Population': 38928346}
# Poland 37846611
# {'Country': 'Poland', 'Population': 37846611}
# Canada 37742154
# {'Country': 'Canada', 'Population': 37742154}
# Morocco 36910560
# {'Country': 'Morocco', 'Population': 36910560}
# Saudi Arabia 34813871
# {'Country': 'Saudi Arabia', 'Population': 34813871}
# Uzbekistan 33469203
# {'Country': 'Uzbekistan', 'Population': 33469203}
# Peru 32971854
# {'Country': 'Peru', 'Population': 32971854}
# Angola 32866272
# {'Country': 'Angola', 'Population': 32866272}
# Malaysia 32365999
# {'Country': 'Malaysia', 'Population': 32365999}
# Mozambique 31255435
# {'Country': 'Mozambique', 'Population': 31255435}
# Ghana 31072940
# {'Country': 'Ghana', 'Population': 31072940}
# Yemen 29825964
# {'Country': 'Yemen', 'Population': 29825964}
# Nepal 29136808
# {'Country': 'Nepal', 'Population': 29136808}
# Venezuela 28435940
# {'Country': 'Venezuela', 'Population': 28435940}
# Madagascar 27691018
# {'Country': 'Madagascar', 'Population': 27691018}
# Cameroon 26545863
# {'Country': 'Cameroon', 'Population': 26545863}
# Côte d'Ivoire 26378274
# {'Country': "Côte d'Ivoire", 'Population': 26378274}
# North Korea 25778816
# {'Country': 'North Korea', 'Population': 25778816}
# Australia 25499884
# {'Country': 'Australia', 'Population': 25499884}
# Niger 24206644
# {'Country': 'Niger', 'Population': 24206644}
# Taiwan 23816775
# {'Country': 'Taiwan', 'Population': 23816775}
# Sri Lanka 21413249
# {'Country': 'Sri Lanka', 'Population': 21413249}
# Burkina Faso 20903273
# {'Country': 'Burkina Faso', 'Population': 20903273}
# Mali 20250833
# {'Country': 'Mali', 'Population': 20250833}
# Romania 19237691
# {'Country': 'Romania', 'Population': 19237691}
# Malawi 19129952
# {'Country': 'Malawi', 'Population': 19129952}
# Chile 19116201
# {'Country': 'Chile', 'Population': 19116201}
# Kazakhstan 18776707
# {'Country': 'Kazakhstan', 'Population': 18776707}
# Zambia 18383955
# {'Country': 'Zambia', 'Population': 18383955}
# Guatemala 17915568
# {'Country': 'Guatemala', 'Population': 17915568}
# Ecuador 17643054
# {'Country': 'Ecuador', 'Population': 17643054}
# Syria 17500658
# {'Country': 'Syria', 'Population': 17500658}
# Netherlands 17134872
# {'Country': 'Netherlands', 'Population': 17134872}
# Senegal 16743927
# {'Country': 'Senegal', 'Population': 16743927}
# Cambodia 16718965
# {'Country': 'Cambodia', 'Population': 16718965}
# Chad 16425864
# {'Country': 'Chad', 'Population': 16425864}
# Somalia 15893222
# {'Country': 'Somalia', 'Population': 15893222}
# Zimbabwe 14862924
# {'Country': 'Zimbabwe', 'Population': 14862924}
# Guinea 13132795
# {'Country': 'Guinea', 'Population': 13132795}
# Rwanda 12952218
# {'Country': 'Rwanda', 'Population': 12952218}
# Benin 12123200
# {'Country': 'Benin', 'Population': 12123200}
# Burundi 11890784
# {'Country': 'Burundi', 'Population': 11890784}
# Tunisia 11818619
# {'Country': 'Tunisia', 'Population': 11818619}
# Bolivia 11673021
# {'Country': 'Bolivia', 'Population': 11673021}
# Belgium 11589623
# {'Country': 'Belgium', 'Population': 11589623}
# Haiti 11402528
# {'Country': 'Haiti', 'Population': 11402528}
# Cuba 11326616
# {'Country': 'Cuba', 'Population': 11326616}
# South Sudan 11193725
# {'Country': 'South Sudan', 'Population': 11193725}
# Dominican Republic 10847910
# {'Country': 'Dominican Republic', 'Population': 10847910}
# Czech Republic (Czechia) 10708981
# {'Country': 'Czech Republic (Czechia)', 'Population': 10708981}
# Greece 10423054
# {'Country': 'Greece', 'Population': 10423054}
# Jordan 10203134
# {'Country': 'Jordan', 'Population': 10203134}
# Portugal 10196709
# {'Country': 'Portugal', 'Population': 10196709}
# Azerbaijan 10139177
# {'Country': 'Azerbaijan', 'Population': 10139177}
# Sweden 10099265
# {'Country': 'Sweden', 'Population': 10099265}
# Honduras 9904607
# {'Country': 'Honduras', 'Population': 9904607}
# United Arab Emirates 9890402
# {'Country': 'United Arab Emirates', 'Population': 9890402}
# Hungary 9660351
# {'Country': 'Hungary', 'Population': 9660351}
# Tajikistan 9537645
# {'Country': 'Tajikistan', 'Population': 9537645}
# Belarus 9449323
# {'Country': 'Belarus', 'Population': 9449323}
# Austria 9006398
# {'Country': 'Austria', 'Population': 9006398}
# Papua New Guinea 8947024
# {'Country': 'Papua New Guinea', 'Population': 8947024}
# Serbia 8737371
# {'Country': 'Serbia', 'Population': 8737371}
# Israel 8655535
# {'Country': 'Israel', 'Population': 8655535}
# Switzerland 8654622
# {'Country': 'Switzerland', 'Population': 8654622}
# Togo 8278724
# {'Country': 'Togo', 'Population': 8278724}
# Sierra Leone 7976983
# {'Country': 'Sierra Leone', 'Population': 7976983}
# Hong Kong 7496981
# {'Country': 'Hong Kong', 'Population': 7496981}
# Laos 7275560
# {'Country': 'Laos', 'Population': 7275560}
# Paraguay 7132538
# {'Country': 'Paraguay', 'Population': 7132538}
# Bulgaria 6948445
# {'Country': 'Bulgaria', 'Population': 6948445}
# Libya 6871292
# {'Country': 'Libya', 'Population': 6871292}
# Lebanon 6825445
# {'Country': 'Lebanon', 'Population': 6825445}
# Nicaragua 6624554
# {'Country': 'Nicaragua', 'Population': 6624554}
# Kyrgyzstan 6524195
# {'Country': 'Kyrgyzstan', 'Population': 6524195}
# El Salvador 6486205
# {'Country': 'El Salvador', 'Population': 6486205}
# Turkmenistan 6031200
# {'Country': 'Turkmenistan', 'Population': 6031200}
# Singapore 5850342
# {'Country': 'Singapore', 'Population': 5850342}
# Denmark 5792202
# {'Country': 'Denmark', 'Population': 5792202}
# Finland 5540720
# {'Country': 'Finland', 'Population': 5540720}
# Congo 5518087
# {'Country': 'Congo', 'Population': 5518087}
# Slovakia 5459642
# {'Country': 'Slovakia', 'Population': 5459642}
# Norway 5421241
# {'Country': 'Norway', 'Population': 5421241}
# Oman 5106626
# {'Country': 'Oman', 'Population': 5106626}
# State of Palestine 5101414
# {'Country': 'State of Palestine', 'Population': 5101414}
# Costa Rica 5094118
# {'Country': 'Costa Rica', 'Population': 5094118}
# Liberia 5057681
# {'Country': 'Liberia', 'Population': 5057681}
# Ireland 4937786
# {'Country': 'Ireland', 'Population': 4937786}
# Central African Republic 4829767
# {'Country': 'Central African Republic', 'Population': 4829767}
# New Zealand 4822233
# {'Country': 'New Zealand', 'Population': 4822233}
# Mauritania 4649658
# {'Country': 'Mauritania', 'Population': 4649658}
# Panama 4314767
# {'Country': 'Panama', 'Population': 4314767}
# Kuwait 4270571
# {'Country': 'Kuwait', 'Population': 4270571}
# Croatia 4105267
# {'Country': 'Croatia', 'Population': 4105267}
# Moldova 4033963
# {'Country': 'Moldova', 'Population': 4033963}
# Georgia 3989167
# {'Country': 'Georgia', 'Population': 3989167}
# Eritrea 3546421
# {'Country': 'Eritrea', 'Population': 3546421}
# Uruguay 3473730
# {'Country': 'Uruguay', 'Population': 3473730}
# Bosnia and Herzegovina 3280819
# {'Country': 'Bosnia and Herzegovina', 'Population': 3280819}
# Mongolia 3278290
# {'Country': 'Mongolia', 'Population': 3278290}
# Armenia 2963243
# {'Country': 'Armenia', 'Population': 2963243}
# Jamaica 2961167
# {'Country': 'Jamaica', 'Population': 2961167}
# Qatar 2881053
# {'Country': 'Qatar', 'Population': 2881053}
# Albania 2877797
# {'Country': 'Albania', 'Population': 2877797}
# Puerto Rico 2860853
# {'Country': 'Puerto Rico', 'Population': 2860853}
# Lithuania 2722289
# {'Country': 'Lithuania', 'Population': 2722289}
# Namibia 2540905
# {'Country': 'Namibia', 'Population': 2540905}
# Gambia 2416668
# {'Country': 'Gambia', 'Population': 2416668}
# Botswana 2351627
# {'Country': 'Botswana', 'Population': 2351627}
# Gabon 2225734
# {'Country': 'Gabon', 'Population': 2225734}
# Lesotho 2142249
# {'Country': 'Lesotho', 'Population': 2142249}
# North Macedonia 2083374
# {'Country': 'North Macedonia', 'Population': 2083374}
# Slovenia 2078938
# {'Country': 'Slovenia', 'Population': 2078938}
# Guinea-Bissau 1968001
# {'Country': 'Guinea-Bissau', 'Population': 1968001}
# Latvia 1886198
# {'Country': 'Latvia', 'Population': 1886198}
# Bahrain 1701575
# {'Country': 'Bahrain', 'Population': 1701575}
# Equatorial Guinea 1402985
# {'Country': 'Equatorial Guinea', 'Population': 1402985}
# Trinidad and Tobago 1399488
# {'Country': 'Trinidad and Tobago', 'Population': 1399488}
# Estonia 1326535
# {'Country': 'Estonia', 'Population': 1326535}
# Timor-Leste 1318445
# {'Country': 'Timor-Leste', 'Population': 1318445}
# Mauritius 1271768
# {'Country': 'Mauritius', 'Population': 1271768}
# Cyprus 1207359
# {'Country': 'Cyprus', 'Population': 1207359}
# Eswatini 1160164
# {'Country': 'Eswatini', 'Population': 1160164}
# Djibouti 988000
# {'Country': 'Djibouti', 'Population': 988000}
# Fiji 896445
# {'Country': 'Fiji', 'Population': 896445}
# Réunion 895312
# {'Country': 'Réunion', 'Population': 895312}
# Comoros 869601
# {'Country': 'Comoros', 'Population': 869601}
# Guyana 786552
# {'Country': 'Guyana', 'Population': 786552}
# Bhutan 771608
# {'Country': 'Bhutan', 'Population': 771608}
# Solomon Islands 686884
# {'Country': 'Solomon Islands', 'Population': 686884}
# Macao 649335
# {'Country': 'Macao', 'Population': 649335}
# Montenegro 628066
# {'Country': 'Montenegro', 'Population': 628066}
# Luxembourg 625978
# {'Country': 'Luxembourg', 'Population': 625978}
# Western Sahara 597339
# {'Country': 'Western Sahara', 'Population': 597339}
# Suriname 586632
# {'Country': 'Suriname', 'Population': 586632}
# Cabo Verde 555987
# {'Country': 'Cabo Verde', 'Population': 555987}
# Micronesia 548914
# {'Country': 'Micronesia', 'Population': 548914}
# Maldives 540544
# {'Country': 'Maldives', 'Population': 540544}
# Malta 441543
# {'Country': 'Malta', 'Population': 441543}
# Brunei  437479
# {'Country': 'Brunei ', 'Population': 437479}
# Guadeloupe 400124
# {'Country': 'Guadeloupe', 'Population': 400124}
# Belize 397628
# {'Country': 'Belize', 'Population': 397628}
# Bahamas 393244
# {'Country': 'Bahamas', 'Population': 393244}
# Martinique 375265
# {'Country': 'Martinique', 'Population': 375265}
# Iceland 341243
# {'Country': 'Iceland', 'Population': 341243}
# Vanuatu 307145
# {'Country': 'Vanuatu', 'Population': 307145}
# French Guiana 298682
# {'Country': 'French Guiana', 'Population': 298682}
# Barbados 287375
# {'Country': 'Barbados', 'Population': 287375}
# New Caledonia 285498
# {'Country': 'New Caledonia', 'Population': 285498}
# French Polynesia 280908
# {'Country': 'French Polynesia', 'Population': 280908}
# Mayotte 272815
# {'Country': 'Mayotte', 'Population': 272815}
# Sao Tome & Principe 219159
# {'Country': 'Sao Tome & Principe', 'Population': 219159}
# Samoa 198414
# {'Country': 'Samoa', 'Population': 198414}
# Saint Lucia 183627
# {'Country': 'Saint Lucia', 'Population': 183627}
# Channel Islands 173863
# {'Country': 'Channel Islands', 'Population': 173863}
# Guam 168775
# {'Country': 'Guam', 'Population': 168775}
# Curaçao 164093
# {'Country': 'Curaçao', 'Population': 164093}
# Kiribati 119449
# {'Country': 'Kiribati', 'Population': 119449}
# Grenada 112523
# {'Country': 'Grenada', 'Population': 112523}
# St. Vincent & Grenadines 110940
# {'Country': 'St. Vincent & Grenadines', 'Population': 110940}
# Aruba 106766
# {'Country': 'Aruba', 'Population': 106766}
# Tonga 105695
# {'Country': 'Tonga', 'Population': 105695}
# U.S. Virgin Islands 104425
# {'Country': 'U.S. Virgin Islands', 'Population': 104425}
# Seychelles 98347
# {'Country': 'Seychelles', 'Population': 98347}
# Antigua and Barbuda 97929
# {'Country': 'Antigua and Barbuda', 'Population': 97929}
# Isle of Man 85033
# {'Country': 'Isle of Man', 'Population': 85033}
# Andorra 77265
# {'Country': 'Andorra', 'Population': 77265}
# Dominica 71986
# {'Country': 'Dominica', 'Population': 71986}
# Cayman Islands 65722
# {'Country': 'Cayman Islands', 'Population': 65722}
# Bermuda 62278
# {'Country': 'Bermuda', 'Population': 62278}
# Marshall Islands 59190
# {'Country': 'Marshall Islands', 'Population': 59190}
# Northern Mariana Islands 57559
# {'Country': 'Northern Mariana Islands', 'Population': 57559}
# Greenland 56770
# {'Country': 'Greenland', 'Population': 56770}
# American Samoa 55191
# {'Country': 'American Samoa', 'Population': 55191}
# Saint Kitts & Nevis 53199
# {'Country': 'Saint Kitts & Nevis', 'Population': 53199}
# Faeroe Islands 48863
# {'Country': 'Faeroe Islands', 'Population': 48863}
# Sint Maarten 42876
# {'Country': 'Sint Maarten', 'Population': 42876}
# Monaco 39242
# {'Country': 'Monaco', 'Population': 39242}
# Turks and Caicos 38717
# {'Country': 'Turks and Caicos', 'Population': 38717}
# Saint Martin 38666
# {'Country': 'Saint Martin', 'Population': 38666}
# Liechtenstein 38128
# {'Country': 'Liechtenstein', 'Population': 38128}
# San Marino 33931
# {'Country': 'San Marino', 'Population': 33931}
# Gibraltar 33691
# {'Country': 'Gibraltar', 'Population': 33691}
# British Virgin Islands 30231
# {'Country': 'British Virgin Islands', 'Population': 30231}
# Caribbean Netherlands 26223
# {'Country': 'Caribbean Netherlands', 'Population': 26223}
# Palau 18094
# {'Country': 'Palau', 'Population': 18094}
# Cook Islands 17564
# {'Country': 'Cook Islands', 'Population': 17564}
# Anguilla 15003
# {'Country': 'Anguilla', 'Population': 15003}
# Tuvalu 11792
# {'Country': 'Tuvalu', 'Population': 11792}
# Wallis & Futuna 11239
# {'Country': 'Wallis & Futuna', 'Population': 11239}
# Nauru 10824
# {'Country': 'Nauru', 'Population': 10824}
# Saint Barthelemy 9877
# {'Country': 'Saint Barthelemy', 'Population': 9877}
# Saint Helena 6077
# {'Country': 'Saint Helena', 'Population': 6077}
# Saint Pierre & Miquelon 5794
# {'Country': 'Saint Pierre & Miquelon', 'Population': 5794}
# Montserrat 4992
# {'Country': 'Montserrat', 'Population': 4992}
# Falkland Islands 3480
# {'Country': 'Falkland Islands', 'Population': 3480}
# Niue 1626
# {'Country': 'Niue', 'Population': 1626}
# Tokelau 1357
# {'Country': 'Tokelau', 'Population': 1357}
# Holy See 801
# {'Country': 'Holy See', 'Population': 801}

# %%
for index, row in df.iterrows():
    print (row["Name"], row["Age"])
# Out:
#   File "<ipython-input-34-a6c5edb04950>", line 1
#     df.$1
#        ^
# SyntaxError: invalid syntax
